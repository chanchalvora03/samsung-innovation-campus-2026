# %% [markdown]
# # Chapter 7: Day 15

# %% [markdown]
# ## Unit 34: Using Python Modules
#
# ### Module
# A module is a Python file that contains functions, variables, or classes.
#
# ### Types:
# - Standard Module - Built-in (math, random, time)
# - External Module - Installed using pip
#
# ### Syntax:
# import module_name
# from module import function
# import module as alias
#
# ### Use of modules:
# - Code reuse
# - Organized structure
# - Easier debugging

# %% [markdown]
# ## Random Module
#
# Used to generate random values for simulations and games

# %%
import random

print("Random float:", random.random())
print("Random integer:", random.randint(1, 10))

data = [10, 20, 30, 40, 50]
print("Random choice:", random.choice(data))
print("Random sample:", random.sample(data, 3))
# Out:
# Random float: 0.16979823574320252
# Random integer: 8
# Random choice: 30
# Random sample: [10, 20, 40]

# %% [markdown]
# Used in games, simulations, and testing randomness

# %% [markdown]
# ## Time Module
#
# Used to control execution delays and measure time

# %%
import time

print("Start")
time.sleep(2) #sleep() pauses execution for a given number of seconds
print("End after 2 seconds")
# Out:
# Start
# End after 2 seconds

# %% [markdown]
# ## Date and Time Handling

# %%
from datetime import date, datetime, time

d = date(2023, 7, 17)
t = time(12, 30, 45)

dt = datetime.combine(d, t)
print(dt)
# Out:
# 2023-07-17 12:30:45

# %%
import pandas as pd 
import numpy as np 
import datetime
from datetime import date, datetime, time, timezone

datetime (2023, 7, 7)
d=date(2023, 7, 17)
t=time(12, 30, 45)
dt=datetime.combine(d, t)
print(dt)
# Out:
# 2023-07-17 12:30:45

# %%
import pandas as pd

dates = pd.date_range(start="2024-01-01", end="2024-01-05")
print(len(dates))
print(dates)
# Out:
# 5
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05'],
#               dtype='datetime64[us]', freq='D')

# %%
import pandas as pd

periods = pd.period_range(start="2024-01-01", end="2024-01-05", freq="D")
print(periods)
# Out:
# PeriodIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#              '2024-01-05'],
#             dtype='period[D]')

# %% [markdown]
# ## OS Module
#
# Used for interacting with the operating system

# %%
import os

print("Current Directory:", os.getcwd())

os.mkdir("test_folder")
print("Folder created")

print("Files:", os.listdir())

os.rmdir("test_folder")
print("Folder removed")
# Out:
# Current Directory: /Users/aliciapereira/Downloads/VS Code/samsung-innovation-campus-2026/samsung-innovation-campus-2026/chapter-7-data-processing-descriptive-statistics-data-visualization
# Folder created
# Files: ['test_folder', 'spotify_dataset.csv', 'spotify_analysis.ipynb', 'output.csv', 'my_playlist.csv', 'day-16.ipynb', 'day-15.ipynb']
# Folder removed

# %% [markdown]
# Used for file handling, directory management, and system operations

# %%
import turtle

colors = ['red', 'yellow', 'blue', 'orange', 'green', 'purple']

t = turtle.Turtle()
turtle.bgcolor('black')

for n in range(36):
    for i in range(6):
        t.color(colors[i])
        t.forward(100)
        t.left(60)
    t.left(10)

turtle.done()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Dice Game (Mini Application)

# %%
import random
import time

def roll_dice(num_dice):
    return [random.randint(1, 6) for _ in range(num_dice)]

def display_roll(player, rolls):
    print(f"{player} rolled: {rolls} → Total = {sum(rolls)}")

def play_game():
    print("Welcome to Dice Game!")
    
    num_dice = int(input("Enter number of dice: "))
    rounds = int(input("Enter number of rounds: "))
    
    user_score = 0
    comp_score = 0
    
    for i in range(1, rounds + 1):
        print(f"\nRound {i}")
        
        input("Press Enter to roll dice...")
        
        user_roll = roll_dice(num_dice)
        comp_roll = roll_dice(num_dice)
        
        display_roll("You", user_roll)
        time.sleep(1)
        display_roll("Computer", comp_roll)
        
        if sum(user_roll) > sum(comp_roll):
            print("You win this round!")
            user_score += 1
        elif sum(comp_roll) > sum(user_roll):
            print("Computer wins this round!")
            comp_score += 1
        else:
            print("It's a tie!")
    
    print("\nFINAL RESULT")
    print(f"You: {user_score} | Computer: {comp_score}")
    
    if user_score > comp_score:
        print("You are the overall winner!")
    elif comp_score > user_score:
        print("Computer wins overall!")
    else:
        print("It's a draw!")

play_game()
# Out:
# Welcome to Dice Game!
#
# Round 1
# You rolled: [1, 1] → Total = 2
# Computer rolled: [3, 2] → Total = 5
# Computer wins this round!
#
# Round 2
# You rolled: [6, 3] → Total = 9
# Computer rolled: [3, 2] → Total = 5
# You win this round!
#
# Round 3
# You rolled: [2, 4] → Total = 6
# Computer rolled: [5, 2] → Total = 7
# Computer wins this round!
#
# FINAL RESULT
# You: 1 | Computer: 2
# Computer wins overall!

# %% [markdown]
# Concepts used:
# - random module → dice rolls
# - time module → delay for better interaction
# - loops → multiple rounds
# - conditionals → winner logic

# %% [markdown]
# ## What I learned
#
# - Modules help organize and reuse code
# - Python provides many built-in modules
# - Random and time modules are useful for simulations
# - OS module allows interaction with system
# - Small applications can be built by combining modules
